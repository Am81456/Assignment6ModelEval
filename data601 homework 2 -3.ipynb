# %% [markdown]
# ## Question 1

# %%
import csv  
import numpy as np 
import seaborn as sns 
import os
import matplotlib.pyplot as plt
from matplotlib import dates as mpl_dates

# %matplotlib inline
from random import randint

# %%
with open ('HW2_People.csv','r') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    next(csv_reader)
    
    for line in csv_reader: 
        print(line)
# Out:
# ['Francisco', 'Maggard', '2009', '3', '13', '38.9']
# ['Mildred', 'Rizvi', '2017', '10', '15', '23.6']
# ['William', 'Lavender', '2016', '3', '1', '23.2']
# ['Evelyn', 'Washington', '2018', '11', '4', '20.1']
# ['Theo', 'Atkinson', '2002', '12', '11', '74.0']
# ['Ella', 'Martinez', '2002', '8', '13', '61.7']
# ['Bryce', 'Dunlap', '2004', '1', '24', '59.8']
# ['David', 'Rutland', '1991', '5', '22', '49.5']
# ['Levi', 'Sproull', '1983', '4', '13', '53.9']
# ['Edwin', 'Lovingood', '2014', '11', '21', '27.4']
# ['Eugene', 'Gibbons', '1968', '9', '13', '66.2']
# ['John', 'Riddle', '2017', '12', '21', '20.8']
# ['Laura', 'Guerrero', '1963', '10', '20', '63.1']
# ['Andrew', 'Patterson', '1980', '5', '1', '62.7']
# ['Darryl', 'Wilkerson', '1991', '9', '1', '62.1']
# ['Debra', 'Hayes', '2013', '1', '24', '28.6']
# ['Michael', 'Stohler', '1963', '7', '22', '49.0']
# ['Amanda', 'Hernandez', '1950', '8', '27', '44.3']
# ['Winnie', 'Adkins', '2009', '12', '22', '36.3']
# ...

# %%
import csv
with open("HW2_People.csv", 'r') as f:
    df = list(csv.reader(f, delimiter=";"))
import numpy as np
df = np.array(df[1:])

# %%
df
# Out:
# array([['Francisco,Maggard,2009,3,13,38.9'],
#        ['Mildred,Rizvi,2017,10,15,23.6'],
#        ['William,Lavender,2016,3,1,23.2'],
#        ...,
#        ['Daniel,Williams,2014,10,14,28.0'],
#        ['Betty,Davis,1988,2,20,63.7'],
#        ['Tamara,Lane,1974,11,2,51.3']], dtype='<U36')

# %%
df.shape
# Out:
# (2000, 1)

# %%
df.columns
# Out:
# Index(['fname', 'lname', 'byear', 'bmonth', 'bday', 'weight'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 840 to 1926
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fname   2000 non-null   object
#  1   lname   2000 non-null   object
#  2   byear   2000 non-null   int64
#  3   bmonth  2000 non-null   int64
#  4   bday    2000 non-null   int64
#  5   weight  2000 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 109.4+ KB

# %% [markdown]
#  Note that first two lists would be strings, the following three are interegs, and the last one is a list floats.

# %%
df.dtypes
# Out:
# fname      object
# lname      object
# byear       int64
# bmonth      int64
# bday        int64
# weight    float64
# dtype: object

# %%
w = np.asarray('weight')

# %%
def edges(df):
    edges = []
    for node in df:
        for neighbour in df[node]:
            edges.append({node, neighbour})

    return edges

print(edges(df))
# Out:
# [{'Frank', 'fname'}, {'Shawn', 'fname'}, {'Charlotte', 'fname'}, {'fname', 'Timothy'}, {'fname', 'Nicholas'}, {'Paul', 'fname'}, {'fname', 'Debra'}, {'Barbara', 'fname'}, {'Mark', 'fname'}, {'Kelly', 'fname'}, {'fname', 'Kathleen'}, {'Wilbert', 'fname'}, {'fname', 'Eric'}, {'fname', 'Delores'}, {'fname', 'David'}, {'fname', 'Michael'}, {'Francisca', 'fname'}, {'Daniel', 'fname'}, {'fname', 'Shane'}, {'Richard', 'fname'}, {'fname', 'Lyndsay'}, {'Randal', 'fname'}, {'John', 'fname'}, {'fname', 'Peter'}, {'fname', 'Amanda'}, {'Leanna', 'fname'}, {'John', 'fname'}, {'Jennifer', 'fname'}, {'Joseph', 'fname'}, {'fname', 'Gerald'}, {'Enrique', 'fname'}, {'Daniel', 'fname'}, {'Donna', 'fname'}, {'fname', 'Robert'}, {'Linda', 'fname'}, {'Jennifer', 'fname'}, {'fname', 'Ronald'}, {'fname', 'Brett'}, {'Richard', 'fname'}, {'Howard', 'fname'}, {'Judith', 'fname'}, {'fname', 'Michael'}, {'Douglas', 'fname'}, {'fname', 'Ann'}, {'Ninfa', 'fname'}, {'fname', 'William'}, {'Deborah', 'fname'}, {'Charl
# ...

# %%
df = open('HW2_People.csv', 'w')
file.write ('')

# %%
import operator 

sort = sorted(df, key=operator.itemgetter(0))

for eachline in sort:
    print (eachline)
# Out:
# ['Aaron,Green,1966,12,13,75.7']
# ['Aaron,Villegas,2019,6,28,16.8']
# ['Abby,Stones,2013,5,7,30.4']
# ['Abel,Johnson,1956,7,29,81.3']
# ['Abigail,Stevens,1984,3,3,54.4']
# ['Abraham,Campbell,1971,2,10,51.3']
# ['Abraham,Olivarez,2013,4,8,28.9']
# ['Adam,Alvine,2000,6,10,78.4']
# ['Adan,Brown,1958,6,14,68.9']
# ['Agripina,Geiger,2012,8,18,33.0']
# ['Aimee,Shine,1961,8,11,51.5']
# ['Alan,Allen,2017,6,9,21.6']
# ['Alan,Deal,1952,8,4,66.7']
# ['Alan,Hollowell,1961,6,26,52.7']
# ['Alan,Ma,1974,7,10,47.9']
# ['Albert,Jones,2013,6,16,28.4']
# ['Albert,Parmer,1968,9,22,60.5']
# ['Alberto,Vance,1982,11,15,57.2']
# ['Alesia,Hoyle,1963,12,30,57.7']
# ['Alex,Bloxham,1958,8,21,73.9']
# ['Alex,Guillory,1976,3,17,55.5']
# ['Alexandra,Baker,1970,10,2,63.5']
# ['Alfred,Eagle,2008,9,9,31.5']
# ['Alfred,Hoover,1994,4,20,73.1']
# ['Alfred,Standish,1984,12,11,65.9']
# ['Alice,Hobby,1970,10,11,65.7']
# ['Alice,Siegal,1973,7,1,63.0']
# ['Alice,Villatora,2012,7,26,30.7']
# ...

# %%
df  = pd.read_csv("HW2_People.csv")

df.sort_values([df.columns[0],df.columns[2]], axis=0, ascending=[True,False], inplace=True)

df.plot(kind='hist',x='byear',y='weight')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Question 2

# %%
df = 'Messi.csv'
df1 = 'Ronaldo.csv'

#df.head()
#df1.head()

import csv
with open ('Messi.csv','r') as csv_file:
    csv_reader = csv.reader(csv_file)

    
    #next(csv_reader)
    
    for line in csv_reader: 
        print(line)
# Out:
# ['\ufeffSeasonStart', 'SeasonEnd', 'ClubApp', 'ClubGoals', 'NatApp', 'NatGoals']
# ['2003', '2004', '15', '5', '2', '3']
# ['2004', '2005', '26', '7', '21', '11']
# ['2005', '2006', '25', '8', '7', '2']
# ['2006', '2007', '36', '17', '14', '6']
# ['2007', '2008', '40', '16', '13', '4']
# ['2008', '2009', '51', '38', '10', '3']
# ['2009', '2010', '53', '47', '10', '2']
# ['2010', '2011', '55', '53', '13', '4']
# ['2011', '2012', '60', '73', '9', '12']
# ['2012', '2013', '50', '60', '7', '6']
# ['2013', '2014', '46', '41', '14', '8']
# ['2014', '2015', '57', '58', '8', '4']
# ['2015', '2016', '49', '41', '11', '8']
# ['2016', '2017', '52', '54', '7', '4']
# ['2017', '2018', '54', '45', '5', '4']
# ['2018', '2019', '50', '51', '10', '5']
# ['2019', '2020', '44', '31', '4', '1']
# ['2020', '2021', '47', '38', '11', '8']

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
df = pd.read_csv('Messi.csv')

df.plot(x = 'SeasonStart',y= 'ClubApp', linestyle = "-")

plt.show()

# %%
df.plot(x= 'SeasonStart', y = 'NatApp', linestyle="--", color='orange')
# Out:
# <AxesSubplot:xlabel='SeasonStart'>

# %%
df.plot(x= 'SeasonStart', y = 'ClubGoals', linestyle="--", color='Pink')
# Out:
# <AxesSubplot:xlabel='SeasonStart'>

# %%
df.plot(x= 'SeasonStart', y = 'NatGoals', linestyle="-", color='Black')
# Out:
# <AxesSubplot:xlabel='SeasonStart'>

# %%
import csv

with open('Ronaldo.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    for line in csv_reader: 
        print(line)
# Out:
# ['\ufeffSeasonStart', 'SeasonEnd', 'ClubApp', 'ClubGoals', 'NatApp', 'NatGoals']
# ['2003', '2004', '40', '6', '16', '7']
# ['2004', '2005', '50', '9', '11', '2']
# ['2005', '2006', '47', '12', '14', '6']
# ['2006', '2007', '53', '23', '10', '5']
# ['2007', '2008', '49', '42', '8', '1']
# ['2008', '2009', '53', '26', '7', '1']
# ['2009', '2010', '35', '33', '11', '3']
# ['2010', '2011', '54', '53', '8', '7']
# ['2011', '2012', '55', '60', '13', '5']
# ['2012', '2013', '55', '55', '9', '10']
# ['2013', '2014', '47', '51', '9', '5']
# ['2014', '2015', '54', '61', '5', '3']
# ['2015', '2016', '48', '51', '13', '13']
# ['2016', '2017', '46', '42', '11', '11']
# ['2017', '2018', '44', '44', '7', '6']
# ['2018', '2019', '43', '28', '10', '14']
# ['2019', '2020', '46', '37', '6', '3']
# ['2020', '2021', '44', '36', '10', '9']

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
df = pd.read_csv('Ronaldo.csv')
df.plot(x = 'SeasonStart',y= 'ClubApp', linestyle = "-")

fig.show()
# Out:
# <ipython-input-232-5cbb7c17fc07>:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df.plot(x= 'SeasonStart', y = 'ClubGoals', linestyle="--", color='green')
# Out:
# <AxesSubplot:xlabel='SeasonStart'>

# %%
df.plot(x= 'SeasonStart', y = 'NatGoals', linestyle="-", color='brown')
# Out:
# <AxesSubplot:xlabel='SeasonStart'>

# %%
df.plot(x= 'SeasonStart', y = 'NatApp', linestyle="--", color='orange')
# Out:
# <AxesSubplot:xlabel='SeasonStart'>

# %% [markdown]
# ## Question 3

# %%
import csv
with open ('season96_97.csv','r') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    #next(csv_reader)
    
    for line in csv_reader: 
        print(line)
# Out:
# ['player_name', 'team_abbreviation', 'age', 'player_height', 'player_weight', 'pts', 'reb', 'ast']
# ['Travis Knight', 'LAL', '22', '213.36', '106.59412', '4.8', '4.5', '0.5']
# ['Matt Fish', 'MIA', '27', '210.82', '106.59412', '0.3', '0.8', '0']
# ['Matt Bullard', 'HOU', '30', '208.28', '106.59412', '4.5', '1.6', '0.9']
# ['Marty Conlon', 'BOS', '29', '210.82', '111.13004', '7.8', '4.4', '1.4']
# ['Martin Muursepp', 'DAL', '22', '205.74', '106.59412', '3.7', '1.6', '0.5']
# ['Martin Lewis', 'TOR', '22', '198.12', '102.0582', '1.6', '0.7', '0.4']
# ['Mark West', 'CLE', '36', '208.28', '111.583632', '3.2', '2.7', '0.3']
# ['Mark Strickland', 'MIA', '26', '208.28', '99.79024', '2', '1.2', '0']
# ['Mark Price', 'GSW', '33', '182.88', '81.64656', '11.3', '2.6', '4.9']
# ['Mark Jackson', 'IND', '32', '190.5', '83.91452', '9.9', '4.8', '11.4']
# ['Mark Hendrickson', 'PHI', '23', '205.74', '99.79024', '2.9', '3.2', '0.1']
# ...

# %%
#import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("season96_97.csv")
#df.plot()  # plots all columns against index
df.plot(kind='scatter',x='player_height',y='player_weight') # scatter plot
# df.plot(kind='hist'

ax.text(155, 65, 'Muggsy Bogues')
ax.text(226, 155, 'Sim Bhullar')
ax.text(233, 137, 'Gheorghe Muresan')

plt.xlabel(" players height")
plt.ylabel(" players Weight")
plt.title("NBA Players Height Vs Weight ")
plt.savefig("out.png")

plt.show()
